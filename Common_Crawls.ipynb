# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_json('http://index.commoncrawl.org/CC-MAIN-2021-21-index?url=*.navy.mil&output=json', lines=True)

# %%
df.dtypes
#df.shape
# Out:
# urlkey                   object
# timestamp        datetime64[ns]
# url                      object
# mime                     object
# mime-detected            object
# status                    int64
# digest                   object
# length                    int64
# offset                    int64
# filename                 object
# languages                object
# encoding                 object
# redirect                 object
# truncated                object
# dtype: object

# %%
df.languages.value_counts()
# Out:
# eng            7215
# eng,fra          17
# eng,dan          12
# eng,por           1
# eng,nya           1
# eng,msa           1
# eng,jpn,dan       1
# eng,deu           1
# eng,jpn           1
# Name: languages, dtype: int64

# %%
for i in range(0,len(df)):
  if df.status[i] == 200:
    print(df.url[i])
# Out:
# https://www.navy.mil/
# https://www.navy.mil/About/our-mission/
# https://www.navy.mil/CHAPLAIN-CORPS/
# https://www.navy.mil/desktopmodules/sharedlibrary/handlers/youtubecaption.ashx?v=Y_poClPZGtc
# https://www.navy.mil/Leadership/Biographies/BioDisplay/Article/2236083/rear-admiral-michael-white/no/
# https://www.navy.mil/Leadership/Biographies/BioDisplay/Article/2236089/admiral-john-aquilino/
# https://www.navy.mil/Leadership/Biographies/BioDisplay/Article/2236103/rear-admiral-martha-herb/
# https://www.navy.mil/Leadership/Biographies/BioDisplay/Article/2236193/rear-admiral-bette-bolivar/
# https://www.navy.mil/Leadership/Biographies/BioDisplay/Article/2236211/vice-admiral-william-galinis/
# https://www.navy.mil/Leadership/Biographies/BioDisplay/Article/2236246/rear-admiral-shane-gahagan/
# https://www.navy.mil/Leadership/Biographies/BioDisplay/Article/2236312/rear-admiral-douglas-beal/
# ...

# %%
names = re

# %%
print(df.url.value_counts())
# Out:
# https://www.navy.mil/robots.txt                                                                                                                                         12
# https://www.doncio.navy.mil/robots.txt                                                                                                                                  10
# https://www.navy.mil/submit/display                                                                                                                                      7
# https://www.c6f.navy.mil/robots.txt                                                                                                                                      7
# https://www.navy.mil/view_single                                                                                                                                         6
# ...

# %%
string = 'https://www.navy.mil/Leadership/Biographies/BioDisplay/Article/2236089/admiral-john-aquilino/'
fields = string.split("/", 25)

# %%
fields[8]
# Out:
# 'admiral-john-aquilino'

# %%
print(fields)
# Out:
# ['https:', '', 'www.navy.mil', 'Leadership', 'Biographies', 'BioDisplay', 'Article', '2236089', 'admiral-john-aquilino', '']
